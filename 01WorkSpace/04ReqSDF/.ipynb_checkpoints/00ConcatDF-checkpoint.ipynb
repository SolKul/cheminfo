# %%
import pandas as pd
import os
import os.path
import sys

#自作モジュールのインポート
p_mod=os.path.join(os.environ['HOME'],'notebooks/99MyModules')
sys.path.append(p_mod)
import descarray as da

#保存先の設定
DataDir=os.path.join(os.environ['HOME'],'notebooks/50Data/')

# %%
#ダウンロード可能な分子のリストのCSVをまとめる
csv_dir='./csv/'
l_csv=[]
for f in os.listdir(csv_dir):
    d_csv={}
    if f.endswith('.csv'):
        d_csv['FN']=f
        d_csv['RP']=os.path.join(csv_dir,f)
        l_csv.append(d_csv)
print(len(l_csv))
# Out:
# 24

# %%
l_csv
# Out:
# [{'FN': 'search_result_006347.csv', 'RP': './csv/search_result_006347.csv'},
#  {'FN': 'search_result_012186.csv', 'RP': './csv/search_result_012186.csv'},
#  {'FN': 'search_result_020042.csv', 'RP': './csv/search_result_020042.csv'},
#  {'FN': 'search_result_031142.csv', 'RP': './csv/search_result_031142.csv'},
#  {'FN': 'search_result_048893.csv', 'RP': './csv/search_result_048893.csv'},
#  {'FN': 'search_result_069192.csv', 'RP': './csv/search_result_069192.csv'},
#  {'FN': 'search_result_077196.csv', 'RP': './csv/search_result_077196.csv'},
#  {'FN': 'search_result_085075.csv', 'RP': './csv/search_result_085075.csv'},
#  {'FN': 'search_result_094154.csv', 'RP': './csv/search_result_094154.csv'},
#  {'FN': 'search_result_102665.csv', 'RP': './csv/search_result_102665.csv'},
#  {'FN': 'search_result_117799.csv', 'RP': './csv/search_result_117799.csv'},
#  {'FN': 'search_result_136739.csv', 'RP': './csv/search_result_136739.csv'},
#  {'FN': 'search_result_141330.csv', 'RP': './csv/search_result_141330.csv'},
#  {'FN': 'search_result_148600.csv', 'RP': './csv/search_result_148600.csv'},
#  {'FN': 'search_result_171055.csv', 'RP': './csv/search_result_171055.csv'},
#  {'FN': 'search_result_199429.csv', 'RP': './csv/search_result_199429.csv'},
#  {'FN': 'search_result_221662.csv', 'RP': './csv/search_result_221662.csv'},
#  {'FN': 'search_result_231920.csv', 'RP': './csv/search_result_231920.csv'},
#  {'FN': 'search_result_243168.csv', 'RP': './csv/search_result_243168.csv'},
#  {'FN': 'search_result_254569.csv', 'RP': './csv/search_result_254569.csv'},
#  {'FN': 'search_result_268266.csv', 'RP': './csv/search_result_268266.csv'},
#  {'FN': 'search_result_282182.csv', 'RP': './csv/search_result_282182.csv'},
#  {'FN': 'search_result_296631.csv', 'RP': './csv/search_result_296631.csv'},
#  {'FN': 'search_result_313475.csv', 'RP': './csv/search_result_313475.csv'}]

# %%
l_df_id=[]
for d_csv in l_csv:
    l_df_id.append(pd.read_csv(d_csv['RP']))
df_id=pd.concat(l_df_id)
df_id.drop_duplicates(inplace=True)
df_id.reset_index(inplace=True)
da.descDf(df_id)
# Out:
# サイズ:(47990, 3)
#    index PCCDB-ID  SMILES
# 0      0     6347   N=C=O
# 1      1     6351   C1CC1
# 2      2     6354   O1CC1
# 3      3     6360  CC(C)C
# 4      4     6363  CC(N)C

# %%
#csvがおかしいところがあり、PCCDB-IDに数字が入ってないことがあるので、
#それ以外は全部int型に
#変換できないものは残る
df_id_int=df_id.copy()
for i in range(df_id.shape[0]):
    try:
        df_id_int.iloc[i,1]=int(df_id.iloc[i]['PCCDB-ID'])
    except:
        print('Error')
# Out:
# Error
# Error
# Error
# Error
# Error
# Error

# %%
#型がintのものだけを残す
df_id_num=df_id_int[df_id_int['PCCDB-ID'].map(type)==int]

# %%
df_id_num.to_pickle('./df_pccdb_id.pkl')

# %%
df_id_num.sort_values(by=['PCCDB-ID'])
# Out:
#        index PCCDB-ID                                          SMILES
# 0          0     6347                                           N=C=O
# 1          1     6351                                           C1CC1
# 2          2     6354                                           O1CC1
# 3          3     6360                                          CC(C)C
# 4          4     6363                                          CC(N)C
# 5          5     6364                                          CC(S)C
# 6          6     6375                                        CN(=O)=O
# 7          7     6377                                     C[C@@H]1CN1
# 8          8     6378                                     C[C@@H]1CO1
# 9          9     6385                                       CC(N)(C)C
# 10        10     6386                                       CC(O)(C)C
# 11        11     6387                                       CC(S)(C)C
# 12        12     6395                                   CS(O)([O])[O]
# 13        13     6396                                    C[Si](C)(C)C
# 14        14     6403                                      CCC(C)(C)C
# 15        15     6404                                      OCC(C)(C)C
# 16        16     6405                                      CCC(O)(C)C
# 17        17     6406                                     N#CC(O)(C)C
# 18        18     6410                                      OOC(C)(C)C
# 19        19     6416                                  CC(=O)C(C)(C)C
# 20        20     6417                                  OC(=O)C(C)(C)C
# 21        21     6425                                CC(C(O)(C)C)(O)C
# 22        22     6440                             OCC([C@@H](O)C)(C)C
# 23        23     6442                                OCC(N(=O)=O)(C)C
# 24        24     6448          CC(=O)O[C@H]1C[C@H]2C([C@]1(C)CC2)(C)C
# 25        25     6454  C=CC[C@@]1([C@@H]2CCC=C2)C(=N[C](=[N]=C1O)=O)O
# 26        26     6455            CC[C@@]1(C(C)C)C(=N[C](=[N]=C1O)=O)O
# 27        27     6464          C=CC[C@@]1(C(C)C)C(=N[C](=[N]=C1O)=O)O
# 28        28     6465                            CCC1(CC)C(=O)CCN=C1O
# 29        29     6470                      CCOC(=O)C1CCN(CC1)c1ccccc1
# ...      ...      ...                                             ...
# 47960   1971   328864                                  CCCC=C=CCN(C)C
# 47961   1972   328865                           OC(=N)CSc1nnc2n1cccc2
# 47962   1973   328893                        CCCCCCOC(=O)c1ccc(cc1)OC
# 47963   1974   328958                      C[C@H](C(=O)O)COCNc1ccccc1
# 47964   1975   328963                          CCOC(=O)CN1C(=S)CSC1=S
# 47965   1976   328975                     CC(=CC(COC(=O)C(=C)C)(C)C)C
# 47966   1977   328977                    CCCCN1C(=O)c2c(C1=O)cc(cc2)N
# 47967   1978   328983                      C[C@]1(C[C@@H](C)C=CC1)C#N
# 47968   1979   329003                             OCC(=O)Nc1ccc(cc1)C
# 47969   1980   329051                               CCC(=CN1CCOCC1)CC
# 47970   1981   329061                                     OCCCCC(=N)O
# 47971   1982   329064            CC[C@@H](OC(=O)c1ccc(cc1)N(=O)=O)C#C
# 47972   1983   329092        CC([C@@H]1[C@@H](C)N(N(C1=O)c1ccccc1)C)C
# 47973   1984   329111                          O=c1c(N)c[nH]c2c1cccc2
# 47974   1985   329113                                    SCCCCCC(=O)O
# 47975   1986   329126                 OC1=Nc2c(C31Nc1c(N3)cccc1)cccc2
# 47976   1987   329134                                 O/N=C/CCCC(=O)O
# 47977   1988   329136                                CCCC(OCC=C)OCC=C
# 47978   1989   329149                    Cc1cccc(c1)N/C(=NC1CCCCC1)/O
# 47979   1990   329151              C[C@H]1CCCC[C@H]1O/C(=Nc1ccccc1)/O
# 47980   1991   329152          C[C@@H]1CCC[C@@H](C1)O/C(=Nc1ccccc1)/O
# 47981   1992   329153                   O/C(=N/c1ccccc1)/OC1(C)CCCCC1
# 47982   1993   329155                              C=C[C@H](n1cncc1)C
# 47983   1994   329160                 N#CC1=C(C#N)CC[C@H](C1)c1ccccc1
# 47984   1995   329205                    OC(=O)/C=C/c1cnc(n1C)N(=O)=O
# 47985   1996   329206                        OCCOC(=O)Cn1ccnc1N(=O)=O
# 47986   1997   329207                  COC(=O)[C@@H](n1ccnc1N(=O)=O)C
# 47987   1998   329218               OC(=N)N/N=C/1CC[C@H](CC1)c1ccccc1
# 47988   1999   329222              CC(=O)[C@@H]1CCC=C[C@@H]1Sc1ccccc1
# 47989   2000   329235               COC(=O)/C(=N/Nc1cccc(c1)C)/C(=O)C
#
# [47984 rows x 3 columns]

# %%
df_id.iloc[47960]
# Out:
# index                 1971
# PCCDB-ID            328864
# SMILES      CCCC=C=CCN(C)C
# Name: 47960, dtype: object

# %%
s_test='328df64'
int(s_test)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-51-a3c6f6445592> in <module>
#       1 s_test='328df64'
# ----> 2 int(s_test)
#
# ValueError: invalid literal for int() with base 10: '328df64'
